# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('StatsData.csv')
df
# Out:
#      Years  Months  Age (months)  Grade  Driver License  \
# 0       16       0           192     10               0
# 1       15      11           191     10               0
# 2       16       1           193     10               0
# 3       15       8           188     10               0
# 4       16       1           193     10               0
# ..     ...     ...           ...    ...             ...
# 98      15       9           189     10               0
# 99      15       1           181     10               0
# 100     15      10           190     10               0
# 101     15       6           186     10               0
# 102     16       0           192     10               0
#
#      Leave Campus for Lunch  Perception About Lunches  Predicted  Residual  \
# 0                         4                         9     1.6306    2.3694
# 1                         0                         8     1.6306   -1.6306
# ...

# %%
df2 = df[['Age (months)', 'Grade', 'Driver License', 'Leave Campus for Lunch', 'Perception About Lunches']]

# %%
df2.head()
# Out:
#    Age (months)  Grade  Driver License  Leave Campus for Lunch  \
# 0           192     10               0                       4
# 1           191     10               0                       0
# 2           193     10               0                       0
# 3           188     10               0                       1
# 4           193     10               0                       0
#
#    Perception About Lunches
# 0                         9
# 1                         8
# 2                         9
# 3                         8
# 4                         8

# %%
df3 = df2[['Driver License', 'Leave Campus for Lunch']]
df3.head()
# Out:
#    Driver License  Leave Campus for Lunch
# 0               0                       4
# 1               0                       0
# 2               0                       0
# 3               0                       1
# 4               0                       0

# %%
duplicates = df3[df3.duplicated()]
duplicates.reset_index(inplace=True)
duplicates
# Out:
#     index  Driver License  Leave Campus for Lunch
# 0       2               0                       0
# 1       4               0                       0
# 2       7               0                       1
# 3       8               0                       0
# 4      10               0                       3
# 5      11               0                       0
# 6      12               0                       0
# 7      13               0                       2
# 8      29               0                       3
# 9      31              18                       5
# 10     32               0                       2
# 11     33               0                       3
# 12     37              21                       5
# 13     39              18                       5
# 14     45               0                       0
# 15     46               0                       3
# 16     48               0                       0
# 17     49               0                       2
# ...

# %%
same = []
dl = duplicates['Driver License']
lunch = duplicates['Leave Campus for Lunch']
print(dl.dtype)
for i in range(len(duplicates)):
    temp = [duplicates.at[i, 'Driver License'], duplicates.at[i, 'Leave Campus for Lunch']]
    if(same.count(temp)==0):
        same.append(temp)
    
print(same)
# Out:
# int64
# [[0, 0], [0, 1], [0, 3], [0, 2], [18, 5], [21, 5], [15, 5], [7, 0], [16, 5], [19, 5], [26, 5], [0, 4], [0, 5]]

# %%
freq = {[0, 0]: 0, [0, 1]: 0, [0, 3]: 0, [0, 2]: 0, [18, 5]: 0, [21, 5]: 0, [15, 5]: 0, [7, 0]: 0, 
        [16, 5]: 0, [19, 5]: 0, [26, 5]: 0, [0, 4]: 0, [0, 5]: 0}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/37/g06bs5f57xx4rxvdyx2sybvmcxw0sg/T/ipykernel_12266/3224272396.py in <module>
# ----> 1 freq = {[0, 0]: 0, [0, 1]: 0, [0, 3]: 0, [0, 2]: 0, [18, 5]: 0, [21, 5]: 0, [15, 5]: 0, [7, 0]: 0,
#       2         [16, 5]: 0, [19, 5]: 0, [26, 5]: 0, [0, 4]: 0, [0, 5]: 0}
#       3 freq
#
# TypeError: unhashable type: 'list'
